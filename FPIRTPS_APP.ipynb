# %%
import joblib
import pandas as pd

data ={
'CZ_KM' :               [158.9],
'DE_KM' :               [0],
'EE_KM' :               [0],
'HU_KM' :               [0],
'LT_KM' :               [0],
'LV_KM' :               [0],
'PL_KM' :               [295.8],
'SE_KM' :               [0],
'SK_KM' :               [0],
'COD_LP':               ['PL40022'],
'START_LOAD_DATA' :     ['01.07.2022'],
'START_LOAD_TIME' :     ['8:00'],
'END_LOAD_DATA' :       ['01.07.2022'],
'END_LOAD_TIME'  :      ['16:00'],
'COD_DP':               ['CZ11000'],
'START_DELIVERY_DATA' : ['02.07.2022'],
'START_DELIVERY_TIME' : ['8:00'],
'END_DELIVERY_DATA' :   ['02.07.2022'],
'END_DELIVERY_TIME' :   ['16:00'],
'VEHICLE_TYPE' :        ['articulated truck'],
'BODY_TYPE' :           ['tautliner'],
'LOAD_UNLOAD_METHOD' :  ['back'],
'EPALE' :               ['0'],
'GOODS_TYPE' :          ['Other'],
'TEMP_MIN' :            [-30],
'TEMP_MAX' :            [30],
'LDM' :                 [13.6],
'TONS' :                [24],
'OTHER_COSTS' :         [0],
'QTY_LOADS' :           [1],
'QTY_DELIVERIES' :      [1],
}

df = pd.DataFrame(data)
# Value Complement
df['CZ_KM'] = df['CZ_KM'].fillna(0)
df['DE_KM'] = df['DE_KM'].fillna(0)
df['EE_KM'] = df['EE_KM'].fillna(0)
df['HU_KM'] = df['HU_KM'].fillna(0)
df['LT_KM'] = df['LT_KM'].fillna(0)
df['LV_KM'] = df['LV_KM'].fillna(0)
df['PL_KM'] = df['PL_KM'].fillna(0)
df['SE_KM'] = df['SE_KM'].fillna(0)
df['SK_KM'] = df['SK_KM'].fillna(0)
df['EPALE'] = df['EPALE'].fillna(0)
df['TEMP_MIN'] = df['TEMP_MIN'].fillna(-30)
df['TEMP_MAX'] = df['TEMP_MAX'].fillna(30)
df['GOODS_TYPE'] = df['GOODS_TYPE'].fillna('Other')
df['BODY_TYPE'] = df['BODY_TYPE'].fillna('Other')
df['LOAD_UNLOAD_METHOD'] = df['LOAD_UNLOAD_METHOD'].fillna('Other')
df['OTHER_COSTS'] = df['OTHER_COSTS'].fillna(0)
df['QTY_LOADS'] = df['QTY_LOADS'].fillna(1)
df['QTY_DELIVERIES'] = df['QTY_DELIVERIES'].fillna(1)

#TIME
df['START_LOAD_TIME'] = df['START_LOAD_TIME'].fillna('8:00:00')
df['END_LOAD_TIME'] = df['END_LOAD_TIME'].fillna('16:00:00')
df['START_DELIVERY_TIME'] = df['START_DELIVERY_TIME'].fillna('8:00:00')
df['END_DELIVERY_TIME'] = df['END_DELIVERY_TIME'].fillna('16:00:00')

# Feature Engineering
df["KM"] = df['CZ_KM'] + df['DE_KM'] + df['EE_KM'] + df['HU_KM'] + df['LT_KM'] + df['LV_KM'] + df['PL_KM'] + df['SE_KM'] + df['SK_KM']
df["TEMP_RANGE"] = df['TEMP_MAX'] - df['TEMP_MIN']

#Date
df['START_LOAD_DATA_DAY'] = pd.DatetimeIndex(df['START_LOAD_DATA']).day
df['START_LOAD_DATA_WEEKDAY'] = pd.DatetimeIndex(df['START_LOAD_DATA']).weekday
df['START_LOAD_DATA_MONTH'] = pd.DatetimeIndex(df['START_LOAD_DATA']).month
df['START_LOAD_DATA_YEAR'] = pd.DatetimeIndex(df['START_LOAD_DATA']).year

df['END_LOAD_DATA_DAY'] = pd.DatetimeIndex(df['END_LOAD_DATA']).day
df['END_LOAD_DATA_WEEKDAY'] = pd.DatetimeIndex(df['END_LOAD_DATA']).weekday
df['END_LOAD_DATA_MONTH'] = pd.DatetimeIndex(df['END_LOAD_DATA']).month
df['END_LOAD_DATA_YEAR'] = pd.DatetimeIndex(df['START_LOAD_DATA']).year

df['START_DELIVERY_DATA_DAY'] = pd.DatetimeIndex(df['START_DELIVERY_DATA']).day
df['START_DELIVERY_DATA_WEEKDAY'] = pd.DatetimeIndex(df['START_DELIVERY_DATA']).day
df['START_DELIVERY_DATA_MONTH'] = pd.DatetimeIndex(df['START_DELIVERY_DATA']).month
df['START_DELIVERY_DATA_YEAR'] = pd.DatetimeIndex(df['START_DELIVERY_DATA']).year

df['END_DELIVERY_DATA_DAY'] = pd.DatetimeIndex(df['END_DELIVERY_DATA']).day
df['END_DELIVERY_DATA_WEEKDAY'] = pd.DatetimeIndex(df['END_DELIVERY_DATA']).weekday
df['END_DELIVERY_DATA_MONTH'] = pd.DatetimeIndex(df['END_DELIVERY_DATA']).month
df['END_DELIVERY_DATA_YEAR'] = pd.DatetimeIndex(df['END_DELIVERY_DATA']).year

df['START_LOAD_TIME_HOUR'] = pd.DatetimeIndex(df['START_LOAD_TIME']).hour
df['START_LOAD_TIME_MINUTE'] = pd.DatetimeIndex(df['START_LOAD_TIME']).minute

df['END_LOAD_TIME_HOUR'] = pd.DatetimeIndex(df['END_LOAD_TIME']).hour
df['END_LOAD_TIME_MINUTE'] = pd.DatetimeIndex(df['END_LOAD_TIME']).minute

df['START_DELIVERY_TIME_HOUR'] = pd.DatetimeIndex(df['START_DELIVERY_TIME']).hour
df['START_DELIVERY_TIME_MINUTE'] = pd.DatetimeIndex(df['START_DELIVERY_TIME']).minute

df['END_DELIVERY_TIME_HOUR'] = pd.DatetimeIndex(df['END_DELIVERY_TIME']).hour
df['END_DELIVERY_TIME_MINUTE'] = pd.DatetimeIndex(df['END_DELIVERY_TIME']).minute

# Relation:
df["COUNTRY_LOAD_PLACE"] = df["COD_LP"].str[:2]
df["COUNTRY_DELIVERY_PLACE"] = df["COD_DP"].str[:2]
df["Relation"] = df["COD_LP"].str[:2] + ' to ' + df["COD_DP"].str[:2]

# Classification load place:
df['LP_CZ'] = df['COD_LP'].str.contains('CZ', regex=False)
df['LP_DE'] = df['COD_LP'].str.contains('DE', regex=False)
df['LP_EE'] = df['COD_LP'].str.contains('EE', regex=False)
df['LP_HU'] = df['COD_LP'].str.contains('HU', regex=False)
df['LP_LT'] = df['COD_LP'].str.contains('LT', regex=False)
df['LP_LV'] = df['COD_LP'].str.contains('LV', regex=False)
df['LP_PL'] = df['COD_LP'].str.contains('PL', regex=False)
df['LP_SE'] = df['COD_LP'].str.contains('SE', regex=False)
df['LP_SK'] = df['COD_LP'].str.contains('SK', regex=False)

df['LP_CZ1'] = df['COD_LP'].str.contains('CZ1', regex=False)
df['LP_CZ2'] = df['COD_LP'].str.contains('CZ2', regex=False)
df['LP_CZ3'] = df['COD_LP'].str.contains('CZ3', regex=False)
df['LP_CZ4'] = df['COD_LP'].str.contains('CZ4', regex=False)
df['LP_CZ5'] = df['COD_LP'].str.contains('CZ5', regex=False)
df['LP_CZ6'] = df['COD_LP'].str.contains('CZ6', regex=False)
df['LP_CZ7'] = df['COD_LP'].str.contains('CZ7', regex=False)

df['LP_DE0'] = df['COD_LP'].str.contains('DE0', regex=False)
df['LP_DE1'] = df['COD_LP'].str.contains('DE1', regex=False)
df['LP_DE2'] = df['COD_LP'].str.contains('DE2', regex=False)
df['LP_DE3'] = df['COD_LP'].str.contains('DE3', regex=False)
df['LP_DE4'] = df['COD_LP'].str.contains('DE4', regex=False)
df['LP_DE5'] = df['COD_LP'].str.contains('DE5', regex=False)
df['LP_DE6'] = df['COD_LP'].str.contains('DE6', regex=False)
df['LP_DE7'] = df['COD_LP'].str.contains('DE7', regex=False)
df['LP_DE8'] = df['COD_LP'].str.contains('DE8', regex=False)
df['LP_DE9'] = df['COD_LP'].str.contains('DE9', regex=False)

df['LP_EE1'] = df['COD_LP'].str.contains('EE1', regex=False)
df['LP_EE2'] = df['COD_LP'].str.contains('EE2', regex=False)
df['LP_EE3'] = df['COD_LP'].str.contains('EE3', regex=False)
df['LP_EE4'] = df['COD_LP'].str.contains('EE4', regex=False)
df['LP_EE5'] = df['COD_LP'].str.contains('EE5', regex=False)
df['LP_EE6'] = df['COD_LP'].str.contains('EE6', regex=False)
df['LP_EE7'] = df['COD_LP'].str.contains('EE7', regex=False)
df['LP_EE8'] = df['COD_LP'].str.contains('EE8', regex=False)
df['LP_EE9'] = df['COD_LP'].str.contains('EE9', regex=False)

df['LP_HU1'] = df['COD_LP'].str.contains('HU1', regex=False)
df['LP_HU2'] = df['COD_LP'].str.contains('HU2', regex=False)
df['LP_HU3'] = df['COD_LP'].str.contains('HU3', regex=False)
df['LP_HU4'] = df['COD_LP'].str.contains('HU4', regex=False)
df['LP_HU5'] = df['COD_LP'].str.contains('HU5', regex=False)
df['LP_HU6'] = df['COD_LP'].str.contains('HU6', regex=False)
df['LP_HU7'] = df['COD_LP'].str.contains('HU7', regex=False)
df['LP_HU8'] = df['COD_LP'].str.contains('HU8', regex=False)
df['LP_HU9'] = df['COD_LP'].str.contains('HU9', regex=False)

df['LP_LT0'] = df['COD_LP'].str.contains('LT0', regex=False)
df['LP_LT1'] = df['COD_LP'].str.contains('LT1', regex=False)
df['LP_LT2'] = df['COD_LP'].str.contains('LT2', regex=False)
df['LP_LT3'] = df['COD_LP'].str.contains('LT3', regex=False)
df['LP_LT4'] = df['COD_LP'].str.contains('LT4', regex=False)
df['LP_LT5'] = df['COD_LP'].str.contains('LT5', regex=False)
df['LP_LT6'] = df['COD_LP'].str.contains('LT6', regex=False)
df['LP_LT7'] = df['COD_LP'].str.contains('LT7', regex=False)
df['LP_LT8'] = df['COD_LP'].str.contains('LT8', regex=False)
df['LP_LT9'] = df['COD_LP'].str.contains('LT9', regex=False)

df['LP_LV1'] = df['COD_LP'].str.contains('LV1', regex=False)
df['LP_LV2'] = df['COD_LP'].str.contains('LV2', regex=False)
df['LP_LV3'] = df['COD_LP'].str.contains('LV3', regex=False)
df['LP_LV4'] = df['COD_LP'].str.contains('LV4', regex=False)
df['LP_LV5'] = df['COD_LP'].str.contains('LV5', regex=False)

df['LP_PL0'] = df['COD_LP'].str.contains('PL0', regex=False)
df['LP_PL1'] = df['COD_LP'].str.contains('PL1', regex=False)
df['LP_PL2'] = df['COD_LP'].str.contains('PL2', regex=False)
df['LP_PL3'] = df['COD_LP'].str.contains('PL3', regex=False)
df['LP_PL4'] = df['COD_LP'].str.contains('PL4', regex=False)
df['LP_PL5'] = df['COD_LP'].str.contains('PL5', regex=False)
df['LP_PL6'] = df['COD_LP'].str.contains('PL6', regex=False)
df['LP_PL7'] = df['COD_LP'].str.contains('PL7', regex=False)
df['LP_PL8'] = df['COD_LP'].str.contains('PL8', regex=False)
df['LP_PL9'] = df['COD_LP'].str.contains('PL9', regex=False)

df['LP_SE1'] = df['COD_LP'].str.contains('SE1', regex=False)
df['LP_SE2'] = df['COD_LP'].str.contains('SE2', regex=False)
df['LP_SE3'] = df['COD_LP'].str.contains('SE3', regex=False)
df['LP_SE4'] = df['COD_LP'].str.contains('SE4', regex=False)
df['LP_SE5'] = df['COD_LP'].str.contains('SE5', regex=False)
df['LP_SE6'] = df['COD_LP'].str.contains('SE6', regex=False)
df['LP_SE7'] = df['COD_LP'].str.contains('SE7', regex=False)
df['LP_SE8'] = df['COD_LP'].str.contains('SE8', regex=False)
df['LP_SE9'] = df['COD_LP'].str.contains('SE9', regex=False)

df['LP_SK0'] = df['COD_LP'].str.contains('SK0', regex=False)
df['LP_SK8'] = df['COD_LP'].str.contains('SK8', regex=False)
df['LP_SK9'] = df['COD_LP'].str.contains('SK9', regex=False)

# Classification delivery place:
df['DP_CZ'] = df['COD_DP'].str.contains('CZ', regex=False)
df['DP_DE'] = df['COD_DP'].str.contains('DE', regex=False)
df['DP_EE'] = df['COD_DP'].str.contains('EE', regex=False)
df['DP_LT'] = df['COD_DP'].str.contains('LT', regex=False)
df['DP_LV'] = df['COD_DP'].str.contains('LV', regex=False)
df['DP_PL'] = df['COD_DP'].str.contains('PL', regex=False)
df['DP_SE'] = df['COD_DP'].str.contains('SE', regex=False)
df['DP_SK'] = df['COD_DP'].str.contains('SK', regex=False)

df['DP_CZ1'] = df['COD_DP'].str.contains('CZ1', regex=False)
df['DP_CZ2'] = df['COD_DP'].str.contains('CZ2', regex=False)
df['DP_CZ3'] = df['COD_DP'].str.contains('CZ3', regex=False)
df['DP_CZ4'] = df['COD_DP'].str.contains('CZ4', regex=False)
df['DP_CZ5'] = df['COD_DP'].str.contains('CZ5', regex=False)
df['DP_CZ6'] = df['COD_DP'].str.contains('CZ6', regex=False)
df['DP_CZ7'] = df['COD_DP'].str.contains('CZ7', regex=False)

df['DP_DE0'] = df['COD_DP'].str.contains('DE0', regex=False)
df['DP_DE1'] = df['COD_DP'].str.contains('DE1', regex=False)
df['DP_DE2'] = df['COD_DP'].str.contains('DE2', regex=False)
df['DP_DE3'] = df['COD_DP'].str.contains('DE3', regex=False)
df['DP_DE4'] = df['COD_DP'].str.contains('DE4', regex=False)
df['DP_DE5'] = df['COD_DP'].str.contains('DE5', regex=False)
df['DP_DE6'] = df['COD_DP'].str.contains('DE6', regex=False)
df['DP_DE7'] = df['COD_DP'].str.contains('DE7', regex=False)
df['DP_DE8'] = df['COD_DP'].str.contains('DE8', regex=False)
df['DP_DE9'] = df['COD_DP'].str.contains('DE9', regex=False)

df['DP_EE1'] = df['COD_DP'].str.contains('EE1', regex=False)
df['DP_EE2'] = df['COD_DP'].str.contains('EE2', regex=False)
df['DP_EE3'] = df['COD_DP'].str.contains('EE3', regex=False)
df['DP_EE4'] = df['COD_DP'].str.contains('EE4', regex=False)
df['DP_EE5'] = df['COD_DP'].str.contains('EE5', regex=False)
df['DP_EE6'] = df['COD_DP'].str.contains('EE6', regex=False)
df['DP_EE7'] = df['COD_DP'].str.contains('EE7', regex=False)
df['DP_EE8'] = df['COD_DP'].str.contains('EE8', regex=False)
df['DP_EE9'] = df['COD_DP'].str.contains('EE9', regex=False)

df['DP_HU1'] = df['COD_DP'].str.contains('HU1', regex=False)
df['DP_HU2'] = df['COD_DP'].str.contains('HU2', regex=False)
df['DP_HU3'] = df['COD_DP'].str.contains('HU3', regex=False)
df['DP_HU4'] = df['COD_DP'].str.contains('HU4', regex=False)
df['DP_HU5'] = df['COD_DP'].str.contains('HU5', regex=False)
df['DP_HU6'] = df['COD_DP'].str.contains('HU6', regex=False)
df['DP_HU7'] = df['COD_DP'].str.contains('HU7', regex=False)
df['DP_HU8'] = df['COD_DP'].str.contains('HU8', regex=False)
df['DP_HU9'] = df['COD_DP'].str.contains('HU9', regex=False)

df['DP_LT0'] = df['COD_DP'].str.contains('LT0', regex=False)
df['DP_LT1'] = df['COD_DP'].str.contains('LT1', regex=False)
df['DP_LT2'] = df['COD_DP'].str.contains('LT2', regex=False)
df['DP_LT3'] = df['COD_DP'].str.contains('LT3', regex=False)
df['DP_LT4'] = df['COD_DP'].str.contains('LT4', regex=False)
df['DP_LT5'] = df['COD_DP'].str.contains('LT5', regex=False)
df['DP_LT6'] = df['COD_DP'].str.contains('LT6', regex=False)
df['DP_LT7'] = df['COD_DP'].str.contains('LT7', regex=False)
df['DP_LT8'] = df['COD_DP'].str.contains('LT8', regex=False)
df['DP_LT9'] = df['COD_DP'].str.contains('LT9', regex=False)

df['DP_LV1'] = df['COD_DP'].str.contains('LV1', regex=False)
df['DP_LV2'] = df['COD_DP'].str.contains('LV2', regex=False)
df['DP_LV3'] = df['COD_DP'].str.contains('LV3', regex=False)
df['DP_LV4'] = df['COD_DP'].str.contains('LV4', regex=False)
df['DP_LV5'] = df['COD_DP'].str.contains('LV5', regex=False)

df['DP_PL0'] = df['COD_DP'].str.contains('PL0', regex=False)
df['DP_PL1'] = df['COD_DP'].str.contains('PL1', regex=False)
df['DP_PL2'] = df['COD_DP'].str.contains('PL2', regex=False)
df['DP_PL3'] = df['COD_DP'].str.contains('PL3', regex=False)
df['DP_PL4'] = df['COD_DP'].str.contains('PL4', regex=False)
df['DP_PL5'] = df['COD_DP'].str.contains('PL5', regex=False)
df['DP_PL6'] = df['COD_DP'].str.contains('PL6', regex=False)
df['DP_PL7'] = df['COD_DP'].str.contains('PL7', regex=False)
df['DP_PL8'] = df['COD_DP'].str.contains('PL8', regex=False)
df['DP_PL9'] = df['COD_DP'].str.contains('PL9', regex=False)

df['DP_SE1'] = df['COD_DP'].str.contains('SE1', regex=False)
df['DP_SE2'] = df['COD_DP'].str.contains('SE2', regex=False)
df['DP_SE3'] = df['COD_DP'].str.contains('SE3', regex=False)
df['DP_SE4'] = df['COD_DP'].str.contains('SE4', regex=False)
df['DP_SE5'] = df['COD_DP'].str.contains('SE5', regex=False)
df['DP_SE6'] = df['COD_DP'].str.contains('SE6', regex=False)
df['DP_SE7'] = df['COD_DP'].str.contains('SE7', regex=False)
df['DP_SE8'] = df['COD_DP'].str.contains('SE8', regex=False)
df['DP_SE9'] = df['COD_DP'].str.contains('SE9', regex=False)

df['DP_SK0'] = df['COD_DP'].str.contains('SK0', regex=False)
df['DP_SK8'] = df['COD_DP'].str.contains('SK8', regex=False)
df['DP_SK9'] = df['COD_DP'].str.contains('SK9', regex=False)

# Classification Relation:
df['CZ_to_DE'] = df['COD_LP'].str.contains('CZ', regex=False) & df['COD_DP'].str.contains('DE', regex=False)
df['CZ_to_EE'] = df['COD_LP'].str.contains('CZ', regex=False) & df['COD_DP'].str.contains('EE', regex=False)
df['CZ_to_HU'] = df['COD_LP'].str.contains('CZ', regex=False) & df['COD_DP'].str.contains('HU', regex=False)
df['CZ_to_LT'] = df['COD_LP'].str.contains('CZ', regex=False) & df['COD_DP'].str.contains('LT', regex=False)   
df['CZ_to_LV'] = df['COD_LP'].str.contains('CZ', regex=False) & df['COD_DP'].str.contains('LV', regex=False)
df['CZ_to_PL'] = df['COD_LP'].str.contains('CZ', regex=False) & df['COD_DP'].str.contains('PL', regex=False)
df['CZ_to_SE'] = df['COD_LP'].str.contains('CZ', regex=False) & df['COD_DP'].str.contains('SE', regex=False)
df['CZ_to_SK'] = df['COD_LP'].str.contains('CZ', regex=False) & df['COD_DP'].str.contains('SK', regex=False)

df['DE_to_CZ'] = df['COD_LP'].str.contains('DE', regex=False) & df['COD_DP'].str.contains('CZ', regex=False)
df['DE_to_EE'] = df['COD_LP'].str.contains('DE', regex=False) & df['COD_DP'].str.contains('EE', regex=False)
df['DE_to_HU'] = df['COD_LP'].str.contains('DE', regex=False) & df['COD_DP'].str.contains('HU', regex=False)
df['DE_to_LT'] = df['COD_LP'].str.contains('DE', regex=False) & df['COD_DP'].str.contains('LT', regex=False)   
df['DE_to_LV'] = df['COD_LP'].str.contains('DE', regex=False) & df['COD_DP'].str.contains('LV', regex=False)
df['DE_to_PL'] = df['COD_LP'].str.contains('DE', regex=False) & df['COD_DP'].str.contains('PL', regex=False)
df['DE_to_SE'] = df['COD_LP'].str.contains('DE', regex=False) & df['COD_DP'].str.contains('SE', regex=False)
df['DE_to_SK'] = df['COD_LP'].str.contains('DE', regex=False) & df['COD_DP'].str.contains('SK', regex=False)

df['EE_to_CZ'] = df['COD_LP'].str.contains('EE', regex=False) & df['COD_DP'].str.contains('CZ', regex=False)
df['EE_to_DE'] = df['COD_LP'].str.contains('EE', regex=False) & df['COD_DP'].str.contains('DE', regex=False)
df['EE_to_HU'] = df['COD_LP'].str.contains('EE', regex=False) & df['COD_DP'].str.contains('HU', regex=False)
df['EE_to_LT'] = df['COD_LP'].str.contains('EE', regex=False) & df['COD_DP'].str.contains('LT', regex=False)   
df['EE_to_LV'] = df['COD_LP'].str.contains('EE', regex=False) & df['COD_DP'].str.contains('LV', regex=False)
df['EE_to_PL'] = df['COD_LP'].str.contains('EE', regex=False) & df['COD_DP'].str.contains('PL', regex=False)
df['EE_to_SE'] = df['COD_LP'].str.contains('EE', regex=False) & df['COD_DP'].str.contains('SE', regex=False)
df['EE_to_SK'] = df['COD_LP'].str.contains('EE', regex=False) & df['COD_DP'].str.contains('SK', regex=False)

df['HU_to_CZ'] = df['COD_LP'].str.contains('HU', regex=False) & df['COD_DP'].str.contains('CZ', regex=False)
df['HU_to_DE'] = df['COD_LP'].str.contains('HU', regex=False) & df['COD_DP'].str.contains('DE', regex=False)
df['HU_to_EE'] = df['COD_LP'].str.contains('HU', regex=False) & df['COD_DP'].str.contains('EE', regex=False)
df['HU_to_LT'] = df['COD_LP'].str.contains('HU', regex=False) & df['COD_DP'].str.contains('LT', regex=False)   
df['HU_to_LV'] = df['COD_LP'].str.contains('HU', regex=False) & df['COD_DP'].str.contains('LV', regex=False)
df['HU_to_PL'] = df['COD_LP'].str.contains('HU', regex=False) & df['COD_DP'].str.contains('PL', regex=False)
df['HU_to_SE'] = df['COD_LP'].str.contains('HU', regex=False) & df['COD_DP'].str.contains('SE', regex=False)
df['HU_to_SK'] = df['COD_LP'].str.contains('HU', regex=False) & df['COD_DP'].str.contains('SK', regex=False)

df['LT_to_CZ'] = df['COD_LP'].str.contains('LT', regex=False) & df['COD_DP'].str.contains('CZ', regex=False)
df['LT_to_DE'] = df['COD_LP'].str.contains('LT', regex=False) & df['COD_DP'].str.contains('DE', regex=False)
df['LT_to_EE'] = df['COD_LP'].str.contains('LT', regex=False) & df['COD_DP'].str.contains('EE', regex=False)  
df['LT_to_HU'] = df['COD_LP'].str.contains('LT', regex=False) & df['COD_DP'].str.contains('HU', regex=False)
df['LT_to_LV'] = df['COD_LP'].str.contains('LT', regex=False) & df['COD_DP'].str.contains('LV', regex=False)
df['LT_to_PL'] = df['COD_LP'].str.contains('LT', regex=False) & df['COD_DP'].str.contains('PL', regex=False)
df['LT_to_SE'] = df['COD_LP'].str.contains('LT', regex=False) & df['COD_DP'].str.contains('SE', regex=False)
df['LT_to_SK'] = df['COD_LP'].str.contains('LT', regex=False) & df['COD_DP'].str.contains('SK', regex=False)

df['LV_to_CZ'] = df['COD_LP'].str.contains('LV', regex=False) & df['COD_DP'].str.contains('CZ', regex=False)
df['LV_to_DE'] = df['COD_LP'].str.contains('LV', regex=False) & df['COD_DP'].str.contains('DE', regex=False)
df['LV_to_EE'] = df['COD_LP'].str.contains('LV', regex=False) & df['COD_DP'].str.contains('EE', regex=False)
df['LV_to_HU'] = df['COD_LP'].str.contains('LV', regex=False) & df['COD_DP'].str.contains('HU', regex=False)
df['LV_to_LT'] = df['COD_LP'].str.contains('LV', regex=False) & df['COD_DP'].str.contains('LT', regex=False)
df['LV_to_PL'] = df['COD_LP'].str.contains('LV', regex=False) & df['COD_DP'].str.contains('PL', regex=False)
df['LV_to_SE'] = df['COD_LP'].str.contains('LV', regex=False) & df['COD_DP'].str.contains('SE', regex=False)
df['LV_to_SK'] = df['COD_LP'].str.contains('LV', regex=False) & df['COD_DP'].str.contains('SK', regex=False)

df['PL_to_CZ'] = df['COD_LP'].str.contains('PL', regex=False) & df['COD_DP'].str.contains('CZ', regex=False)
df['PL_to_DE'] = df['COD_LP'].str.contains('PL', regex=False) & df['COD_DP'].str.contains('DE', regex=False)
df['PL_to_EE'] = df['COD_LP'].str.contains('PL', regex=False) & df['COD_DP'].str.contains('EE', regex=False)
df['PL_to_HU'] = df['COD_LP'].str.contains('PL', regex=False) & df['COD_DP'].str.contains('HU', regex=False) 
df['PL_to_LT'] = df['COD_LP'].str.contains('PL', regex=False) & df['COD_DP'].str.contains('LT', regex=False)
df['PL_to_LV'] = df['COD_LP'].str.contains('PL', regex=False) & df['COD_DP'].str.contains('LV', regex=False)
df['PL_to_SE'] = df['COD_LP'].str.contains('PL', regex=False) & df['COD_DP'].str.contains('SE', regex=False)
df['PL_to_SK'] = df['COD_LP'].str.contains('PL', regex=False) & df['COD_DP'].str.contains('SK', regex=False)

df['SE_to_CZ'] = df['COD_LP'].str.contains('SE', regex=False) & df['COD_DP'].str.contains('CZ', regex=False)
df['SE_to_DE'] = df['COD_LP'].str.contains('SE', regex=False) & df['COD_DP'].str.contains('DE', regex=False)
df['SE_to_EE'] = df['COD_LP'].str.contains('SE', regex=False) & df['COD_DP'].str.contains('EE', regex=False)  
df['SE_to_HU'] = df['COD_LP'].str.contains('SE', regex=False) & df['COD_DP'].str.contains('HU', regex=False) 
df['SE_to_LT'] = df['COD_LP'].str.contains('SE', regex=False) & df['COD_DP'].str.contains('LT', regex=False)
df['SE_to_LV'] = df['COD_LP'].str.contains('SE', regex=False) & df['COD_DP'].str.contains('LV', regex=False)
df['SE_to_PL'] = df['COD_LP'].str.contains('SE', regex=False) & df['COD_DP'].str.contains('PL', regex=False)
df['SE_to_SK'] = df['COD_LP'].str.contains('SE', regex=False) & df['COD_DP'].str.contains('SK', regex=False)

df['SK_to_CZ'] = df['COD_LP'].str.contains('SK', regex=False) & df['COD_DP'].str.contains('CZ', regex=False)
df['SK_to_DE'] = df['COD_LP'].str.contains('SK', regex=False) & df['COD_DP'].str.contains('DE', regex=False)
df['SK_to_EE'] = df['COD_LP'].str.contains('SK', regex=False) & df['COD_DP'].str.contains('EE', regex=False)
df['SK_to_HU'] = df['COD_LP'].str.contains('SK', regex=False) & df['COD_DP'].str.contains('HU', regex=False)
df['SK_to_LT'] = df['COD_LP'].str.contains('SK', regex=False) & df['COD_DP'].str.contains('LT', regex=False)
df['SK_to_LV'] = df['COD_LP'].str.contains('SK', regex=False) & df['COD_DP'].str.contains('LV', regex=False)
df['SK_to_PL'] = df['COD_LP'].str.contains('SK', regex=False) & df['COD_DP'].str.contains('PL', regex=False)
df['SK_to_SE'] = df['COD_LP'].str.contains('SK', regex=False) & df['COD_DP'].str.contains('SE', regex=False)

# Classification cargo type:
df['Other'] = df['GOODS_TYPE'].str.contains('Other', regex=False)
df['Frozen Food'] = df['GOODS_TYPE'].str.contains('Frozen Food', regex=False)
df['Drinks'] = df['GOODS_TYPE'].str.contains('Drinks', regex=False)
df['Yoghurt'] = df['GOODS_TYPE'].str.contains('Yoghurt', regex=False)
df['Steel'] = df['GOODS_TYPE'].str.contains('Steel', regex=False)
df['Food'] = df['GOODS_TYPE'].str.contains('Food', regex=False)
df['Margarine'] = df['GOODS_TYPE'].str.contains('Margarine', regex=False)
df['Frozen Fish'] = df['GOODS_TYPE'].str.contains('Frozen Fish', regex=False)
df['Wallpapers'] = df['GOODS_TYPE'].str.contains('Wallpapers', regex=False)
df['Water'] = df['GOODS_TYPE'].str.contains('Water', regex=False)
df['Frozen'] = df['GOODS_TYPE'].str.contains('Frozen', regex=False)
df['Bisquits'] = df['GOODS_TYPE'].str.contains('Bisquits', regex=False)
df['Heaters'] = df['GOODS_TYPE'].str.contains('Heaters', regex=False)
df['refills'] = df['GOODS_TYPE'].str.contains('refills', regex=False)
df['candles'] = df['GOODS_TYPE'].str.contains('candles', regex=False)
df['ICE CREAM'] = df['GOODS_TYPE'].str.contains('ICE CREAM', regex=False)
df['HIGIENIC ARTICLES'] = df['GOODS_TYPE'].str.contains('HIGIENIC ARTICLES', regex=False)



# Classification body type
df['BODY_TYPE'] = df['BODY_TYPE'].str.upper()

df['BOX'] = df['BODY_TYPE'].str.contains('BOX', regex=False)
df['COIL TROUGH'] = df['BODY_TYPE'].str.contains('COIL TROUGH', regex=False)
df['CURTAIN'] = df['BODY_TYPE'].str.contains('CURTAIN', regex=False)
df['FLATBED TRUCK'] = df['BODY_TYPE'].str.contains('FLATBED TRUCK', regex=False)
df['MEGA'] = df['BODY_TYPE'].str.contains('MEGA', regex=False)
df['REFRIGERATOR'] = df['BODY_TYPE'].str.contains('REFRIGERATOR', regex=False)
df['RIGID'] = df['BODY_TYPE'].str.contains('RIGID', regex=False)
df['TAUTLINER'] = df['BODY_TYPE'].str.contains('TAUTLINER', regex=False)
df['THERMO'] = df['BODY_TYPE'].str.contains('THERMO', regex=False)

# Classification load and unload methon
df['LOAD_UNLOAD_METHOD'] = df['LOAD_UNLOAD_METHOD'].str.upper()

df['BACK'] = df['LOAD_UNLOAD_METHOD'].str.contains('BACK', regex=False)
df['TOP'] = df['LOAD_UNLOAD_METHOD'].str.contains('TOP', regex=False)
df['SIDE'] = df['LOAD_UNLOAD_METHOD'].str.contains('SIDE', regex=False)

df = df[df['KM'] !=0]
#Change false into 0 and true into 1
df = df*1

# Separate features and labels
X = df[['CZ_KM',
 'DE_KM',
 'EE_KM',
'HU_KM',
 'LT_KM',
 'LV_KM',
 'PL_KM',
 'SE_KM',
 'SK_KM',
'KM',
'EPALE','QTY_DELIVERIES','QTY_LOADS',
 'START_LOAD_DATA_WEEKDAY',
 'START_LOAD_DATA_MONTH',
 'START_LOAD_DATA_YEAR',
 'END_LOAD_DATA_WEEKDAY',
 'END_LOAD_DATA_MONTH',
 'END_LOAD_DATA_YEAR',
 'START_DELIVERY_DATA_WEEKDAY',
 'START_DELIVERY_DATA_MONTH',
 'START_DELIVERY_DATA_YEAR',
 'END_DELIVERY_DATA_WEEKDAY',
 'END_DELIVERY_DATA_MONTH',
 'END_DELIVERY_DATA_YEAR',
 'LP_CZ',
 'LP_DE',
 'LP_EE',
 'LP_LT',
 'LP_LV',
 'LP_PL',
 'LP_SE',
 'LP_SK',
 'LP_CZ1',
 'LP_CZ2',
 'LP_CZ3',
 'LP_CZ4',
 'LP_CZ5',
 'LP_CZ6',
 'LP_CZ7',
 'LP_DE0',
 'LP_DE1',
 'LP_DE2',
 'LP_DE3',
 'LP_DE4',
 'LP_DE5',
 'LP_DE6',
 'LP_DE7',
 'LP_DE8',
 'LP_DE9',
 'LP_EE1',
 'LP_EE2',
 'LP_EE3',
 'LP_EE4',
 'LP_EE5',
 'LP_EE6',
 'LP_EE7',
 'LP_EE8',
 'LP_EE9',
'LP_HU1',
 'LP_HU2',
 'LP_HU3',
 'LP_HU4',
 'LP_HU5',
 'LP_HU6',
 'LP_HU7',
 'LP_HU8',
 'LP_HU9',
 'LP_LT0',
 'LP_LT1',
 'LP_LT2',
 'LP_LT3',
 'LP_LT4',
 'LP_LT5',
 'LP_LT6',
 'LP_LT7',
 'LP_LT8',
 'LP_LT9',
 'LP_LV1',
 'LP_LV2',
 'LP_LV3',
 'LP_LV4',
 'LP_LV5',
 'LP_PL0',
 'LP_PL1',
 'LP_PL2',
 'LP_PL3',
 'LP_PL4',
 'LP_PL5',
 'LP_PL6',
 'LP_PL7',
 'LP_PL8',
 'LP_PL9',
 'LP_SE1',
 'LP_SE2',
 'LP_SE3',
 'LP_SE4',
 'LP_SE5',
 'LP_SE6',
 'LP_SE7',
 'LP_SE8',
 'LP_SE9',
 'LP_SK0',
 'LP_SK8',
 'LP_SK9',
 'DP_CZ',
 'DP_DE',
 'DP_EE',
 'DP_LT',
 'DP_LV',
 'DP_PL',
 'DP_SE',
 'DP_SK',
 'DP_CZ1',
 'DP_CZ2',
 'DP_CZ3',
 'DP_CZ4',
 'DP_CZ5',
 'DP_CZ6',
 'DP_CZ7',
 'DP_DE0',
 'DP_DE1',
 'DP_DE2',
 'DP_DE3',
 'DP_DE4',
 'DP_DE5',
 'DP_DE6',
 'DP_DE7',
 'DP_DE8',
 'DP_DE9',
 'DP_EE1',
 'DP_EE2',
 'DP_EE3',
 'DP_EE4',
 'DP_EE5',
 'DP_EE6',
 'DP_EE7',
 'DP_EE8',
 'DP_EE9',
'DP_HU1',
 'DP_HU2',
 'DP_HU3',
 'DP_HU4',
 'DP_HU5',
 'DP_HU6',
 'DP_HU7',
 'DP_HU8',
 'DP_HU9',
 'DP_LT0',
 'DP_LT1',
 'DP_LT2',
 'DP_LT3',
 'DP_LT4',
 'DP_LT5',
 'DP_LT6',
 'DP_LT7',
 'DP_LT8',
 'DP_LT9',
 'DP_LV1',
 'DP_LV2',
 'DP_LV3',
 'DP_LV4',
 'DP_LV5',
 'DP_PL0',
 'DP_PL1',
 'DP_PL2',
 'DP_PL3',
 'DP_PL4',
 'DP_PL5',
 'DP_PL6',
 'DP_PL7',
 'DP_PL8',
 'DP_PL9',
 'DP_SE1',
 'DP_SE2',
 'DP_SE3',
 'DP_SE4',
 'DP_SE5',
 'DP_SE6',
 'DP_SE7',
 'DP_SE8',
 'DP_SE9',
 'DP_SK0',
 'DP_SK8',
 'DP_SK9',
 'CZ_to_DE',
 'CZ_to_EE',
            'CZ_to_HU',
 'CZ_to_LT',
 'CZ_to_LV',
 'CZ_to_PL',
 'CZ_to_SE',
 'CZ_to_SK',
 'DE_to_CZ',
 'DE_to_EE',
           'DE_to_HU',
 'DE_to_LT',
 'DE_to_LV',
 'DE_to_PL',
 'DE_to_SE',
 'DE_to_SK',
 'EE_to_CZ',
 'EE_to_DE',
            'EE_to_HU',
 'EE_to_LT',
 'EE_to_LV',
 'EE_to_PL',
 'EE_to_SE',
 'EE_to_SK',
 'LT_to_CZ',
 'LT_to_DE',
 'LT_to_EE',
            'LT_to_HU',
 'LT_to_LV',
 'LT_to_PL',
 'LT_to_SE',
 'LT_to_SK',
 'LV_to_CZ',
 'LV_to_DE',
 'LV_to_EE',
            'LV_to_HU',
 'LV_to_LT',
 'LV_to_PL',
 'LV_to_SE',
 'LV_to_SK',
 'PL_to_CZ',
 'PL_to_DE',
 'PL_to_EE',
            'PL_to_HU',
 'PL_to_LT',
 'PL_to_LV',
 'PL_to_SE',
 'PL_to_SK',
 'SE_to_CZ',
 'SE_to_DE',
 'SE_to_EE',
            'SE_to_HU',
 'SE_to_LT',
 'SE_to_LV',
 'SE_to_PL',
 'SE_to_SK',
 'SK_to_CZ',
 'SK_to_DE',
 'SK_to_EE',
            'SK_to_HU',
 'SK_to_LT',
 'SK_to_LV',
 'SK_to_PL',
 'SK_to_SE',
 'Other',
 'Frozen Food',
 'Drinks',
 'Yoghurt',
 'Steel',
 'Food',
 'Margarine',
 'Frozen Fish',
 'Wallpapers',
 'Water',
 'Frozen',
 'Bisquits',
 'Heaters',
 'refills',
 'candles',
 'ICE CREAM',
 'HIGIENIC ARTICLES',
 'BACK','TOP','SIDE',
           'BOX','COIL TROUGH','CURTAIN','FLATBED TRUCK','MEGA','REFRIGERATOR','RIGID','TAUTLINER','THERMO'
          ]].values
model = joblib.load('FPIRTPS_MODEL.pkl')
predictions = model.predict(X)
predictions
# Out:
# array([486.0805813])
